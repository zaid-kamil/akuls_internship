# %%
from dputils.scrape import extract_many, get_webpage_data

# %%
url = "https://www.flipkart.com/search?q=mobiles&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off"
soup = get_webpage_data(url)

# %%
target = {
    'tag': 'div',
    'attrs':{'class':'_1YokD2 _3Mn1Gg'}
}
items = {
    'tag': 'div',
    'attrs':{'class':'_1AtVbE col-12-12'}
}
title = {
    'tag': 'div',
    'attrs':{'class':'_4rR01T'}
}
price = {
    'tag': 'div',
    'attrs':{'class':'_30jeq3 _1_WHN1'}
}
rating = {
    'tag': 'div',
    'attrs':{'class':'_3LWZlK'}
}
link = {
    'tag': 'a',
    'attrs':{'class':'_1fQZEK'},
    'output':'href'
}

# %%
from bs4 import BeautifulSoup

# %%
def extract_many_1(soup : BeautifulSoup, **selectors) -> list:
    """
    Extracts several data items from given BeautifulSoup object
    Output will be a list containing dicts of {title : data_stored_in_selectors}
    
    Args:
    soup (BeautifulSoup): Contains entire page data as BeautifulSoup object. Data items will be extracted from this object
    **selectors (dict): dict of {key : info}
        info must be written in following manner:
            first key is 'tag' with value as tag from where data is obtained
            second key is 'attrs' with value as dict containing id or class information
        Valid Examples:
            title =  {'tag' : 'h2', 'attrs' : {'class':'a-size-mini a-spacing-none a-color-base s-line-clamp-2'}}
            priceDict = {'tag' : 'span', 'attrs' : {'class' : 'a-price-whole'}}
        
        target is a special selector and can be added to specify which section of html code should data be extracted from
        Example of target use:
            target = {'tag' : 'div', 'attrs' : {'class':'s-main-slot s-result-list s-search-results sg-row'}}
        
        items is a mandatory selector which refers to the repeating blocks of html code from soup object
        Example of item use:
            items =  {'tag' : 'div', 'attrs' : {'class':'s-result-item'}}

        Valid call: 
            soup = get_webpage_data("https://www.amazon.com/s?k=headphones&crid=1DUUWW6PEVAJ1&sprefix=headphones%2Caps%2C161&ref=nb_sb_noss_1")
            extract_many(soup, 
                target = {'tag' : 'div', 'attrs' : {'class':'s-main-slot s-result-list s-search-results sg-row'}},
                items =  {'tag' : 'div', 'attrs' : {'class':'s-result-item'}},
                title =  {'tag' : 'h2', 'attrs' : {'class':'a-size-mini a-spacing-none a-color-base s-line-clamp-2'}})
    """
    if 'target' in selectors:
        tag = selectors['target'].get('tag')
        attrs = selectors['target'].get('attrs')
        if tag is None:
            print("Please give valid selectors")
            print("Example: target = {'tag' : 'div', 'attrs' : {...}")
            return None
        else:
            target = soup.find(tag, attrs)
            if target is None:
                print(f"Could not find target section with this {tag} and {attrs}")
                return None
    else:
        target = soup
    print(len(target.text))
    data_list = []
    if 'items' in selectors:
        print('tag',selectors['items'].get('tag'))
        print('attrs',selectors['items'].get('attrs'))
        items = target.find_all(selectors['items'].get('tag'), attrs = selectors['items'].get('attrs'))
        items_count = len(items)
        if items_count == 0:
            print("No data found")
            return data_list
        else:
            print(f"{items_count} items found")
            selectors.pop('target')
            selectors.pop('items')
            for idx, item in enumerate(items):
                data = {}
                try:
                    for key,info in selectors.items():
                        tag = info.get('tag', 'div')
                        attrs = info.get('attrs', None) 
                        output = info.get('output', 'text')
                        if output == 'text':
                            data[key] = item.find(tag, attrs = attrs).text.strip()
                        elif output == 'href':
                            data[key] = item.find(tag, attrs = attrs).attrs.get('href') 
                        elif output == 'src': 
                            data[key] = item.find(tag, attrs = attrs).attrs.get('src')     
                        else:
                            print('Not suitable output')
                    print(data)
                    data_list.append(data)
                except:
                    print("Item skipped at index:", idx)
            else:
                print("All items extracted")
            return data_list
    else:
        print("items is required as a parameter containing dict containing tag, attrs as keys")
        print("Example: items = {'tag' : 'div', 'attrs' : {...}")

# %%
out= extract_many_1(soup, target=target, items=items, title=title, price=price, rating=rating, link=link)
# Out:
# 13757
# 9281
# tag div
# attrs {'class': '_1AtVbE col-12-12'}
# 26 items found
# {'title': 'POCO C31 (Royal Blue, 64 GB)', 'price': '₹9,999', 'rating': '4.4', 'link': '/poco-c31-royal-blue-64-gb/p/itm19effae969b86?pid=MOBG73E7GKQK4KZP&lid=LSTMOBG73E7GKQK4KZPR5ICMK&marketplace=FLIPKART&q=mobiles&store=tyy%2F4io&srno=s_1_1&otracker=search&otracker1=search&fm=organic&iid=dc1256a9-9052-42f4-a50a-954ce272eaf4.MOBG73E7GKQK4KZP.SEARCH&ppt=None&ppn=None&ssid=bkcsh4mqdc0000001655357261831&qH=eb4af0bf07c16429'}
# {'title': 'realme C20 (Cool Blue, 32 GB)', 'price': '₹7,499', 'rating': '4.4', 'link': '/realme-c20-cool-blue-32-gb/p/itmea1903897436b?pid=MOBGF4894MEWZJGV&lid=LSTMOBGF4894MEWZJGVW425N5&marketplace=FLIPKART&q=mobiles&store=tyy%2F4io&srno=s_1_2&otracker=search&otracker1=search&fm=organic&iid=dc1256a9-9052-42f4-a50a-954ce272eaf4.MOBGF4894MEWZJGV.SEARCH&ppt=None&ppn=None&ssid=bkcsh4mqdc0000001655357261831&qH=eb4af0bf07c16429'}
# {'title': 'realme C20 (Cool Grey, 32 GB)', 'price': '₹7,499', 'rating': '4.4', 'link': '/realme-c20-cool-grey-32-gb/p/itmea1903897436b?pid=MOBGF489SQZCFHYA&lid=LSTMOBGF489SQZCFHYAGB7SDS&marketplace=FLIPKART&q=mobiles&store=tyy%2F4io&srno=s_1_3&otracker=search&otracker1=search&fm=organic&iid=dc1256a9-9052-42f4-a50a-954ce272eaf4.MOBGF489SQZCFHYA.SEARCH&ppt=None&ppn=None&ssid=bkcsh4mqdc0000001655357261831&qH=eb4af0bf07c16429'}
# {'title': 'SAMSUNG Galaxy F22 (Denim Blue, 64 GB)', 'price': '₹10,499', 'rating': '4.3', 'link': '/samsung-galaxy-f22-denim-blue-64-gb/p/itmce0a6baf0d54d?pid=MOBG43UGBTGGB99V&lid=LSTMOBG43UGBTGGB99VLZACSD&marketplace=FLIPKART&q=mobiles&store=tyy%2F4io&srno=s_1_4&otracker=search&otracker1=search&fm=organic&iid=dc1256a9-9052-42f4-a50a-954ce272eaf4.MOBG43UGBTGGB99V.SEARCH&ppt=None&ppn=None&ssid=bkcsh4mqdc0000001655357261831&qH=eb4af0bf07c16429'}
# {'title': 'SAMSUNG Galaxy F22 (Denim Black, 64 GB)', 'price': '₹10,499', 'rating': '4.3', 'link': '/samsung-galaxy-f22-denim-black-64-gb/p/itm6f47a19cb79ae?pid=MOBG43UGC3PYCBZF&lid=LSTMOBG43UGC3PYCBZFSIRYTE&marketplace=FLIPKART&q=mobiles&store=tyy%2F4io&srno=s_1_5&otracker=search&otracker1=search&fm=organic&iid=dc1256a9-9052-42f4-a50a-954ce272eaf4.MOBG43UGC3PYCBZF.SEARCH&ppt=None&ppn=None&ssid=bkcsh4mqdc0000001655357261831&qH=eb4af0bf07c16429'}
# {'title': 'SAMSUNG Galaxy F12 (Sea Green, 64 GB)', 'price': '₹9,499', 'rating': '4.3', 'link': '/samsung-galaxy-f12-sea-green-64-gb/p/itm4d3582cd695fd?pid=MOBGFG794YPQ9RAE&lid=LSTMOBGFG794YPQ9RAEGUPPTW&marketplace=FLIPKART&q=mobiles&store=tyy%2F4io&srno=s_1_6&otracker=search&otracker1=search&fm=organic&iid=dc1256a9-9052-42f4-a50a-954ce272eaf4.MOBGFG794YPQ9RAE.SEARCH&ppt=None&ppn=None&ssid=bkcsh4mqdc0000001655357261831&qH=eb4af0bf07c16429'}
# {'title': 'REDMI Note 10S (Frost White, 64 GB)', 'price': '₹12,999', 'rating': '4.4', 'link': '/redmi-note-10s-frost-white-64-gb/p/itm2059d1d0cfd67?pid=MOBGAHD8TKZGPYJW&lid=LSTMOBGAHD8TKZGPYJWDRWTJG&marketplace=FLIPKART&q=mobiles&store=tyy%2F4io&srno=s_1_7&otracker=search&otracker1=search&fm=organic&iid=dc1256a9-9052-42f4-a50a-954ce272eaf4.MOBGAHD8TKZGPYJW.SEARCH&ppt=None&ppn=None&ssid=bkcsh4mqdc0000001655357261831&qH=eb4af0bf07c16429'}
# {'title': 'REDMI Note 10S (Shadow Black, 64 GB)', 'price': '₹12,999', 'rating': '4.4', 'link': '/redmi-note-10s-shadow-black-64-gb/p/itmf77ca8e5edabf?pid=MOBGAHD8HKGFRKGF&lid=LSTMOBGAHD8HKGFRKGFKWCIRK&marketplace=FLIPKART&q=mobiles&store=tyy%2F4io&srno=s_1_8&otracker=search&otracker1=search&fm=organic&iid=dc1256a9-9052-42f4-a50a-954ce272eaf4.MOBGAHD8HKGFRKGF.SEARCH&ppt=None&ppn=None&ssid=bkcsh4mqdc0000001655357261831&qH=eb4af0bf07c16429'}
# {'title': 'REDMI Note 10S (Cosmic Purple, 64 GB)', 'price': '₹12,999', 'rating': '4.4', 'link': '/redmi-note-10s-cosmic-purple-64-gb/p/itm2a1b4b90344a3?pid=MOBG62SFDH9CEJWG&lid=LSTMOBG62SFDH9CEJWGQ0FZG8&marketplace=FLIPKART&q=mobiles&store=tyy%2F4io&srno=s_1_9&otracker=search&otracker1=search&fm=organic&iid=dc1256a9-9052-42f4-a50a-954ce272eaf4.MOBG62SFDH9CEJWG.SEARCH&ppt=None&ppn=None&ssid=bkcsh4mqdc0000001655357261831&qH=eb4af0bf07c16429'}
# {'title': 'REDMI Note 10S (Deep Sea Blue, 64 GB)', 'price': '₹12,999', 'rating': '4.4', 'link': '/redmi-note-10s-deep-sea-blue-64-gb/p/itmdd3b943d713b8?pid=MOBGAHD8GWKMFWFG&lid=LSTMOBGAHD8GWKMFWFGQXE9RS&marketplace=FLIPKART&q=mobiles&store=tyy%2F4io&srno=s_1_10&otracker=search&otracker1=search&fm=organic&iid=dc1256a9-9052-42f4-a50a-954ce272eaf4.MOBGAHD8GWKMFWFG.SEARCH&ppt=None&ppn=None&ssid=bkcsh4mqdc0000001655357261831&qH=eb4af0bf07c16429'}
# {'title': 'Infinix HOT 12 Play (Horizon Blue, 64 GB)', 'price': '₹8,499', 'rating': '4.3', 'link': '/infinix-hot-12-play-horizon-blue-64-gb/p/itmd9c1091d0a662?pid=MOBGE2KYCFZA7BRB&lid=LSTMOBGE2KYCFZA7BRBUNTJVL&marketplace=FLIPKART&q=mobiles&store=tyy%2F4io&srno=s_1_11&otracker=search&otracker1=search&fm=organic&iid=dc1256a9-9052-42f4-a50a-954ce272eaf4.MOBGE2KYCFZA7BRB.SEARCH&ppt=None&ppn=None&ssid=bkcsh4mqdc0000001655357261831&qH=eb4af0bf07c16429'}
# {'title': 'SAMSUNG Galaxy F22 (Denim Blue, 128 GB)', 'price': '₹12,499', 'rating': '4.3', 'link': '/samsung-galaxy-f22-denim-blue-128-gb/p/itm30c755943bea0?pid=MOBG43UGRSMJXTMH&lid=LSTMOBG43UGRSMJXTMH8AUDHE&marketplace=FLIPKART&q=mobiles&store=tyy%2F4io&srno=s_1_12&otracker=search&otracker1=search&fm=organic&iid=dc1256a9-9052-42f4-a50a-954ce272eaf4.MOBG43UGRSMJXTMH.SEARCH&ppt=None&ppn=None&ssid=bkcsh4mqdc0000001655357261831&qH=eb4af0bf07c16429'}
# {'title': 'Infinix HOT 12 Play (Daylight Green, 64 GB)', 'price': '₹8,499', 'rating': '4.3', 'link': '/infinix-hot-12-play-daylight-green-64-gb/p/itmd9c1091d0a662?pid=MOBGE2KY6JUTSNCP&lid=LSTMOBGE2KY6JUTSNCPGWOMYY&marketplace=FLIPKART&q=mobiles&store=tyy%2F4io&srno=s_1_13&otracker=search&otracker1=search&fm=organic&iid=dc1256a9-9052-42f4-a50a-954ce272eaf4.MOBGE2KY6JUTSNCP.SEARCH&ppt=None&ppn=None&ssid=bkcsh4mqdc0000001655357261831&qH=eb4af0bf07c16429'}
# {'title': 'Infinix HOT 12 Play (Racing Black, 64 GB)', 'price': '₹8,499', 'rating': '4.3', 'link': '/infinix-hot-12-play-racing-black-64-gb/p/itmd9c1091d0a662?pid=MOBGE2KYNTFHTXUW&lid=LSTMOBGE2KYNTFHTXUWDFJ0XM&marketplace=FLIPKART&q=mobiles&store=tyy%2F4io&srno=s_1_14&otracker=search&otracker1=search&fm=organic&iid=dc1256a9-9052-42f4-a50a-954ce272eaf4.MOBGE2KYNTFHTXUW.SEARCH&ppt=None&ppn=None&ssid=bkcsh4mqdc0000001655357261831&qH=eb4af0bf07c16429'}
# {'title': 'POCO C31 (Shadow Gray, 64 GB)', 'price': '₹9,999', 'rating': '4.4', 'link': '/poco-c31-shadow-gray-64-gb/p/itm162375acb8370?pid=MOBG73E7UBFXXMCH&lid=LSTMOBG73E7UBFXXMCHYSYSJR&marketplace=FLIPKART&q=mobiles&store=tyy%2F4io&srno=s_1_15&otracker=search&otracker1=search&fm=organic&iid=dc1256a9-9052-42f4-a50a-954ce272eaf4.MOBG73E7UBFXXMCH.SEARCH&ppt=None&ppn=None&ssid=bkcsh4mqdc0000001655357261831&qH=eb4af0bf07c16429'}
# {'title': 'REDMI 10 (Pacific Blue, 64 GB)', 'price': '₹9,999', 'rating': '4.4', 'link': '/redmi-10-pacific-blue-64-gb/p/itm0f2a6a2112b75?pid=MOBGC9GYCHQZK9GW&lid=LSTMOBGC9GYCHQZK9GW1PUFXX&marketplace=FLIPKART&q=mobiles&store=tyy%2F4io&srno=s_1_16&otracker=search&otracker1=search&fm=organic&iid=dc1256a9-9052-42f4-a50a-954ce272eaf4.MOBGC9GYCHQZK9GW.SEARCH&ppt=None&ppn=None&ssid=bkcsh4mqdc0000001655357261831&qH=eb4af0bf07c16429'}
# {'title': 'realme 9 5G (Stargaze White, 128 GB)', 'price': '₹17,499', 'rating': '4.3', 'link': '/realme-9-5g-stargaze-white-128-gb/p/itm4f3814d50ff53?pid=MOBGC2Q5JHRNRFKY&lid=LSTMOBGC2Q5JHRNRFKYWQMNHT&marketplace=FLIPKART&q=mobiles&store=tyy%2F4io&srno=s_1_17&otracker=search&otracker1=search&fm=organic&iid=dc1256a9-9052-42f4-a50a-954ce272eaf4.MOBGC2Q5JHRNRFKY.SEARCH&ppt=None&ppn=None&ssid=bkcsh4mqdc0000001655357261831&qH=eb4af0bf07c16429'}
# {'title': 'POCO M3 Pro 5G (Yellow, 128 GB)', 'price': '₹12,499', 'rating': '4.2', 'link': '/poco-m3-pro-5g-yellow-128-gb/p/itm023855e180d52?pid=MOBG3P55YEAPRX4Q&lid=LSTMOBG3P55YEAPRX4QAVUREF&marketplace=FLIPKART&q=mobiles&store=tyy%2F4io&srno=s_1_18&otracker=search&otracker1=search&fm=organic&iid=dc1256a9-9052-42f4-a50a-954ce272eaf4.MOBG3P55YEAPRX4Q.SEARCH&ppt=None&ppn=None&ssid=bkcsh4mqdc0000001655357261831&qH=eb4af0bf07c16429'}
# {'title': 'REDMI 10 (Caribbean Green, 64 GB)', 'price': '₹9,999', 'rating': '4.4', 'link': '/redmi-10-caribbean-green-64-gb/p/itmbfb8dfcdd6e10?pid=MOBGC9GYQGGKWEU3&lid=LSTMOBGC9GYQGGKWEU3NDJY6R&marketplace=FLIPKART&q=mobiles&store=tyy%2F4io&srno=s_1_19&otracker=search&otracker1=search&fm=organic&iid=dc1256a9-9052-42f4-a50a-954ce272eaf4.MOBGC9GYQGGKWEU3.SEARCH&ppt=None&ppn=None&ssid=bkcsh4mqdc0000001655357261831&qH=eb4af0bf07c16429'}
# {'title': 'SAMSUNG Galaxy F22 (Denim Black, 128 GB)', 'price': '₹12,499', 'rating': '4.3', 'link': '/samsung-galaxy-f22-denim-black-128-gb/p/itm9f921a1b4f96c?pid=MOBG43UGFGYU4K4B&lid=LSTMOBG43UGFGYU4K4B0FR1R0&marketplace=FLIPKART&q=mobiles&store=tyy%2F4io&srno=s_1_20&otracker=search&otracker1=search&fm=organic&iid=dc1256a9-9052-42f4-a50a-954ce272eaf4.MOBG43UGFGYU4K4B.SEARCH&ppt=None&ppn=None&ssid=bkcsh4mqdc0000001655357261831&qH=eb4af0bf07c16429'}
# {'title': 'REDMI 9i Sport (Metallic Blue, 64 GB)', 'price': '₹8,799', 'rating': '4.4', 'link': '/redmi-9i-sport-metallic-blue-64-gb/p/itmeb95d0b4616cc?pid=MOBG6WQWQZZMGQCU&lid=LSTMOBG6WQWQZZMGQCUR9J4PR&marketplace=FLIPKART&q=mobiles&store=tyy%2F4io&srno=s_1_21&otracker=search&otracker1=search&fm=organic&iid=dc1256a9-9052-42f4-a50a-954ce272eaf4.MOBG6WQWQZZMGQCU.SEARCH&ppt=None&ppn=None&ssid=bkcsh4mqdc0000001655357261831&qH=eb4af0bf07c16429'}
# {'title': 'realme 9 5G (Meteor Black, 64 GB)', 'price': '₹15,999', 'rating': '4.5', 'link': '/realme-9-5g-meteor-black-64-gb/p/itm4f3814d50ff53?pid=MOBGC2Q5TGTGRBHR&lid=LSTMOBGC2Q5TGTGRBHRNIVGPU&marketplace=FLIPKART&q=mobiles&store=tyy%2F4io&srno=s_1_22&otracker=search&otracker1=search&fm=organic&iid=dc1256a9-9052-42f4-a50a-954ce272eaf4.MOBGC2Q5TGTGRBHR.SEARCH&ppt=None&ppn=None&ssid=bkcsh4mqdc0000001655357261831&qH=eb4af0bf07c16429'}
# {'title': 'REDMI 10 (Midnight Black, 64 GB)', 'price': '₹9,999', 'rating': '4.4', 'link': '/redmi-10-midnight-black-64-gb/p/itmd93641e4ebb47?pid=MOBGC9GYEBH3GZ4E&lid=LSTMOBGC9GYEBH3GZ4EOWOH9V&marketplace=FLIPKART&q=mobiles&store=tyy%2F4io&srno=s_1_23&otracker=search&otracker1=search&fm=organic&iid=dc1256a9-9052-42f4-a50a-954ce272eaf4.MOBGC9GYEBH3GZ4E.SEARCH&ppt=None&ppn=None&ssid=bkcsh4mqdc0000001655357261831&qH=eb4af0bf07c16429'}
# {'title': 'MOTOROLA e40 (Carbon Gray, 64 GB)', 'price': '₹9,999', 'rating': '4.1', 'link': '/motorola-e40-carbon-gray-64-gb/p/itm0ca635007c9e2?pid=MOBG2EMWUMUFGSZE&lid=LSTMOBG2EMWUMUFGSZE5BRN80&marketplace=FLIPKART&q=mobiles&store=tyy%2F4io&srno=s_1_24&otracker=search&otracker1=search&fm=organic&iid=dc1256a9-9052-42f4-a50a-954ce272eaf4.MOBG2EMWUMUFGSZE.SEARCH&ppt=None&ppn=None&ssid=bkcsh4mqdc0000001655357261831&qH=eb4af0bf07c16429'}
# Item skipped at index: 24
# Item skipped at index: 25
# All items extracted

# %%
import pandas as pd

# %%
df  = pd.DataFrame(out)

# %%
df
# Out:
#                                           title    price rating  \
# 0                  POCO C31 (Royal Blue, 64 GB)   ₹9,999    4.4
# 1                 realme C20 (Cool Blue, 32 GB)   ₹7,499    4.4
# 2                 realme C20 (Cool Grey, 32 GB)   ₹7,499    4.4
# 3        SAMSUNG Galaxy F22 (Denim Blue, 64 GB)  ₹10,499    4.3
# 4       SAMSUNG Galaxy F22 (Denim Black, 64 GB)  ₹10,499    4.3
# 5         SAMSUNG Galaxy F12 (Sea Green, 64 GB)   ₹9,499    4.3
# 6           REDMI Note 10S (Frost White, 64 GB)  ₹12,999    4.4
# 7          REDMI Note 10S (Shadow Black, 64 GB)  ₹12,999    4.4
# 8         REDMI Note 10S (Cosmic Purple, 64 GB)  ₹12,999    4.4
# 9         REDMI Note 10S (Deep Sea Blue, 64 GB)  ₹12,999    4.4
# 10    Infinix HOT 12 Play (Horizon Blue, 64 GB)   ₹8,499    4.3
# 11      SAMSUNG Galaxy F22 (Denim Blue, 128 GB)  ₹12,499    4.3
# 12  Infinix HOT 12 Play (Daylight Green, 64 GB)   ₹8,499    4.3
# 13    Infinix HOT 12 Play (Racing Black, 64 GB)   ₹8,499    4.3
# 14                POCO C31 (Shadow Gray, 64 GB)   ₹9,999    4.4
# 15               REDMI 10 (Pacific Blue, 64 GB)   ₹9,999    4.4
# 16         realme 9 5G (Stargaze White, 128 GB)  ₹17,499    4.3
# 17              POCO M3 Pro 5G (Yellow, 128 GB)  ₹12,499    4.2
# 18            REDMI 10 (Caribbean Green, 64 GB)   ₹9,999    4.4
# 19     SAMSUNG Galaxy F22 (Denim Black, 128 GB)  ₹12,499    4.3
# 20        REDMI 9i Sport (Metallic Blue, 64 GB)   ₹8,799    4.4
# 21            realme 9 5G (Meteor Black, 64 GB)  ₹15,999    4.5
# 22             REDMI 10 (Midnight Black, 64 GB)   ₹9,999    4.4
# 23            MOTOROLA e40 (Carbon Gray, 64 GB)   ₹9,999    4.1
#
#                                                  link
# 0   /poco-c31-royal-blue-64-gb/p/itm19effae969b86?...
# 1   /realme-c20-cool-blue-32-gb/p/itmea1903897436b...
# 2   /realme-c20-cool-grey-32-gb/p/itmea1903897436b...
# 3   /samsung-galaxy-f22-denim-blue-64-gb/p/itmce0a...
# 4   /samsung-galaxy-f22-denim-black-64-gb/p/itm6f4...
# 5   /samsung-galaxy-f12-sea-green-64-gb/p/itm4d358...
# 6   /redmi-note-10s-frost-white-64-gb/p/itm2059d1d...
# 7   /redmi-note-10s-shadow-black-64-gb/p/itmf77ca8...
# 8   /redmi-note-10s-cosmic-purple-64-gb/p/itm2a1b4...
# 9   /redmi-note-10s-deep-sea-blue-64-gb/p/itmdd3b9...
# 10  /infinix-hot-12-play-horizon-blue-64-gb/p/itmd...
# 11  /samsung-galaxy-f22-denim-blue-128-gb/p/itm30c...
# 12  /infinix-hot-12-play-daylight-green-64-gb/p/it...
# 13  /infinix-hot-12-play-racing-black-64-gb/p/itmd...
# 14  /poco-c31-shadow-gray-64-gb/p/itm162375acb8370...
# 15  /redmi-10-pacific-blue-64-gb/p/itm0f2a6a2112b7...
# 16  /realme-9-5g-stargaze-white-128-gb/p/itm4f3814...
# 17  /poco-m3-pro-5g-yellow-128-gb/p/itm023855e180d...
# 18  /redmi-10-caribbean-green-64-gb/p/itmbfb8dfcdd...
# 19  /samsung-galaxy-f22-denim-black-128-gb/p/itm9f...
# 20  /redmi-9i-sport-metallic-blue-64-gb/p/itmeb95d...
# 21  /realme-9-5g-meteor-black-64-gb/p/itm4f3814d50...
# 22  /redmi-10-midnight-black-64-gb/p/itmd93641e4eb...
# 23  /motorola-e40-carbon-gray-64-gb/p/itm0ca635007...
